# %% [markdown]
# <a href="https://colab.research.google.com/github/Tsukumo-999/web3-knock100-first-half/blob/master/s1-1_get_block.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Web3 Python 100本ノック：第1章
# ## §1-1：ブロックチェーンの残高を取得する
#
# このノートブックは、イーサリアムブロックチェーン上のアドレスの残高を取得するサンプルです。
#
# > **注意**: 各セルを順番に実行してください。セルの実行には `Shift + Enter` を押します。
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Tsukumo-999/web3-knock100-first-half/blob/master/s1-1_get_block.ipynb)
#
# ## 準備
#
# Colabでこのノートブックを実行する場合は、まず以下のセルを実行して `web3` ライブラリをインストールしてください。

# %%
# Colabで使用する場合、最初にweb3ライブラリをインストールする（!pip install web3==7.16.0を実行）
# ※ ローカル環境では既にインストール済みの場合はコメントアウトあるいはこのセルを実行しないこと
# !pip install web3==7.16.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 28.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.5/587.5 kB 35.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.5/102.5 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.1/374.1 kB 27.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.8/176.8 kB 15.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 59.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 86.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Web3.pyライブラリのインポート

# %%
# Web3.pyライブラリのインポート
from web3 import Web3

# %% [markdown]
# ## 残高取得

# %% [markdown]
# ### RPCノードの設定
# 制限が緩めで安定しているパブリックRPCノードを使用

# %%
RPC_URL = "https://eth.drpc.org"
print(f"RPC URL: {RPC_URL}")
# Out:
# RPC URL: https://eth.drpc.org

# %% [markdown]
# ### User-Agentヘッダーの設定
# パブリックノードのBot弾き（WAF）を回避するため、ブラウザのUser-Agentを設定する

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
}
print("User-Agent ヘーダー設定完了")
# Out:
# User-Agent ヘーダー設定完了

# %% [markdown]
# ### Web3接続のテスト
# プロバイダの初期化（ヘッダーとタイムアウトを設定）

# %%
print(f" {RPC_URL} へ接続します...\n")

try:
    w3 = Web3(Web3.HTTPProvider(RPC_URL, request_kwargs={'headers': headers, 'timeout': 5}))

    # 最新のブロック情報を取得
    latest_block = w3.eth.block_number
    print(f" 接続成功！ (現在の最新ブロック: {latest_block})\n")

except Exception as e:
    print(f" 接続失敗: {type(e).__name__} - {e}")
# Out:
#  https://eth.drpc.org へ接続します...
#
#  接続成功！ (現在の最新ブロック: 25658503)

# %% [markdown]
# ### アドレスの残高を取得

# %%
# アドレスの残高を取得
print("--- アドレス残高の確認 ---")

try:
    # イーサリアム共同創設者 Vitalik Buterin 氏の公開アドレス
    target_address = "0xd8dA6BF26964aF9D7eEd9e03E53415D37aA96045"

    # get_balance で残高を取得（単位は最小単位の「Wei」）
    balance_wei = w3.eth.get_balance(target_address)

    # from_wei で Wei を「ETH」表記に変換
    balance_eth = w3.from_wei(balance_wei, "ether")

    print(f"Target : {target_address}")
    print(f"Balance: {balance_eth:.4f} ETH")

except Exception as e:
    print(f"[error] データ取得中にエラー発生: {e}")
# Out:
# --- アドレス残高の確認 ---
# Target : 0xd8dA6BF26964aF9D7eEd9e03E53415D37aA96045
# Balance: 6.6323 ETH

# %% [markdown]
# ### Etherscanで確認
# 正しく取得できたかEatherscanで確認してみます。以下のリンクを踏むと公式ブロックチェーンエクスプローラーである Etherscan で確認できます。
#
# [Etherscan Address 0xd8dA6BF26964aF9D7eEd9e03E53415D37aA96045](https://etherscan.io/address/0xd8dA6BF26964aF9D7eEd9e03E53415D37aA96045)

# %% [markdown]
# ## おまけ：別のアドレスの残高を確認
# 残高を確認したいアドレス(Ethernet)を入力すれば確認できます。(サーバによっては厳重なセキュリティがありはじかれることもあります。)

# %%
my_address = input("確認したいアドレスを入力してください: ")

try:
    balance_wei = w3.eth.get_balance(my_address)
    balance_eth = w3.from_wei(balance_wei, "ether")
    print(f"\nTarget : {my_address}")
    print(f"Balance: {balance_eth:.4f} ETH")
except Exception as e:
    print(f"❌ データ取得中にエラー発生: {e}")
# Out:
# Target : 0x6c42A0b5D13059fA36D5567aB04F83BAB57bBF0e
# Balance: 9.6906 ETH
